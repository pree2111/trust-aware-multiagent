# %%
import ollama

class OllamaClient:

    def __init__(self, model="qwen2.5:3b"):
        self.model = model

    def ask(self, prompt):

        response = ollama.chat(
            model=self.model,
            messages=[
                {
                    "role": "user",
                    "content": prompt
                }
            ]
        )

        return response["message"]["content"]

# %%
client = OllamaClient()

print(
    client.ask(
        "What is prompt injection?"
    )
)
# Out:
# Prompt injection refers to the practice of manipulating or injecting data into prompts (the initial text used for generating content) in ways that exploit vulnerabilities within an AI model's training data, architecture, or implementation. This can occur in various applications and services where AI models are integrated, such as chatbots, language models, or recommendation systems.
#
# ### Key Points:
#
# 1. **Exploitation of Vulnerabilities**: Prompt injection leverages known weaknesses or oversights in the system to manipulate the output. These vulnerabilities could be related to how data is processed, trained, or interpreted by the AI model.
#
# 2. **Types of Exploits**:
#    - **Semantic Manipulation**: Modifying prompts to steer the generated response towards a desired result that may not align with the original intent.
#    - **Data Poisoning**: Introducing misleading or harmful information in the training data (though this is often considered a separate issue).
#    - **Trickery and Deception**: Using the prompt to mislead the AI model into generating content that is misleading, harmful, or inappropriate.
#
# 3. **Impact**:
#    - **Misinformation and Misuse**: The most common issue is the spread of misinformation, which can have severe consequences in fields like journalism, health information, and public safety.
#    - **Bias Amplification**: If prompts are crafted to amplify certain biases within the model’s training data or architecture.
#
# 4. **Prevention**:
#    - Implementing robust security measures such as input validation, access controls, and monitoring for anomalous activity.
#    - Regularly auditing AI systems for vulnerabilities and updating them accordingly.
#    - Training models with diverse and balanced datasets to reduce over-reliance on specific prompt patterns that might be exploited.
#
# Understanding prompt injection is crucial for developers and users of AI technologies, as it helps in identifying potential risks and implementing safeguards to mitigate the impact.
